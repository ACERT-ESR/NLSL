# %%
run runexample.py 1
# Out:
# about to run nlsl

# %%
import nlsl

# %%
nlsl.parameters.param1
# Out:
# you tried to get param1
# you tried to set param1 to
#  1

# %%
nlsl.parameters.param1
# Out:
# you tried to get param1
# Help on NoneType object:
#
# class NoneType(object)
#  |  Methods defined here:
#  |
#  |  __hash__(...)
#  |      x.__hash__() <==> hash(x)
#  |
#  |  __repr__(...)
#  |      x.__repr__() <==> repr(x)

# %%
a = nlsl.parameters.param1()
# Out:
# you tried to get param1
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-68a0b21dd61a> in <module>()
# ----> 1 a = nlsl.parameters.param1()
#
# TypeError: 'NoneType' object is not callable
